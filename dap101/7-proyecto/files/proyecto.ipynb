# %% [markdown]
# # Proyecto

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols

plt.rcParams["figure.figsize"] = (10, 8)

# %% [markdown]
# ## Analisis exploratorio de datos

# %%
encuesta_vivienda = pd.read_csv("endutih_vivienda_anual_2019_enc.csv")

# %%
encuesta_vivienda.columns
# Out:
# Index(['energia_electrica', 'refrigerador', 'lavadora', 'auto_propio',
#        'personas_vivienda', 'mismo_gasto', 'TLOC', 'ESTRATO', 'material_1',
#        'material_2', 'material_3', 'fuente_agua_1', 'fuente_agua_2',
#        'fuente_agua_3', 'fuente_agua_4', 'fuente_agua_5', 'fuente_agua_6',
#        'conexion_drenaje_1', 'conexion_drenaje_2', 'conexion_drenaje_3',
#        'conexion_drenaje_4', 'conexion_drenaje_5', 'tipo_poblacion_R',
#        'tipo_poblacion_U'],
#       dtype='object')

# %%
encuesta_vivienda.shape
# Out:
# (21163, 24)

# %%
encuesta_vivienda.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21163 entries, 0 to 21162
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   energia_electrica   21163 non-null  int64
#  1   refrigerador        21163 non-null  int64
#  2   lavadora            21163 non-null  int64
#  3   auto_propio         21163 non-null  int64
#  4   personas_vivienda   21163 non-null  int64
#  5   mismo_gasto         21163 non-null  int64
#  6   TLOC                21163 non-null  int64
#  7   ESTRATO             21163 non-null  int64
#  8   material_1          21163 non-null  int64
#  9   material_2          21163 non-null  int64
#  10  material_3          21163 non-null  int64
#  11  fuente_agua_1       21163 non-null  int64
#  12  fuente_agua_2       21163 non-null  int64
#  13  fuente_agua_3       21163 non-null  int64
#  14  fuente_agua_4       21163 non-null  int64
#  15  fuente_agua_5       21163 non-null  int64
#  16  fuente_agua_6       21163 non-null  int64
#  17  conexion_drenaje_1  21163 non-null  int64
#  18  conexion_drenaje_2  21163 non-null  int64
#  19  conexion_drenaje_3  21163 non-null  int64
#  20  conexion_drenaje_4  21163 non-null  int64
#  21  conexion_drenaje_5  21163 non-null  int64
#  22  tipo_poblacion_R    21163 non-null  int64
#  23  tipo_poblacion_U    21163 non-null  int64
# dtypes: int64(24)
# memory usage: 3.9 MB

# %% [markdown]
# ### Estadistica descriptiva

# %%
encuesta_vivienda.describe()
# Out:
#        energia_electrica  refrigerador      lavadora   auto_propio  \
# count       21163.000000  21163.000000  21163.000000  21163.000000
# mean            0.992581      0.885271      0.729670      0.482588
# std             0.085813      0.318702      0.444141      0.499709
# min             0.000000      0.000000      0.000000      0.000000
# 25%             1.000000      1.000000      0.000000      0.000000
# 50%             1.000000      1.000000      1.000000      0.000000
# 75%             1.000000      1.000000      1.000000      1.000000
# max             1.000000      1.000000      1.000000      1.000000
#
#        personas_vivienda   mismo_gasto          TLOC       ESTRATO  \
# count       21163.000000  21163.000000  21163.000000  21163.000000
# mean            3.618863      1.018476      2.412371      2.179228
# std             1.858446      0.134667      1.328592      1.024259
# min             1.000000      1.000000      1.000000      1.000000
# 25%             2.000000      1.000000      1.000000      1.000000
# 50%             4.000000      1.000000      2.000000      2.000000
# 75%             5.000000      1.000000      4.000000      3.000000
# max            22.000000      2.000000      4.000000      4.000000
#
#          material_1    material_2  ...  fuente_agua_4  fuente_agua_5  \
# count  21163.000000  21163.000000  ...   21163.000000   21163.000000
# mean       0.034069      0.524500  ...       0.010915       0.025469
# std        0.181410      0.499411  ...       0.103907       0.157548
# min        0.000000      0.000000  ...       0.000000       0.000000
# 25%        0.000000      0.000000  ...       0.000000       0.000000
# 50%        0.000000      1.000000  ...       0.000000       0.000000
# 75%        0.000000      1.000000  ...       0.000000       0.000000
# max        1.000000      1.000000  ...       1.000000       1.000000
#
#        fuente_agua_6  conexion_drenaje_1  conexion_drenaje_2  \
# count   21163.000000        21163.000000        21163.000000
# mean        0.037707            0.659264            0.288286
# std         0.190492            0.473968            0.452976
# min         0.000000            0.000000            0.000000
# 25%         0.000000            0.000000            0.000000
# 50%         0.000000            1.000000            0.000000
# 75%         0.000000            1.000000            1.000000
# max         1.000000            1.000000            1.000000
#
#        conexion_drenaje_3  conexion_drenaje_4  conexion_drenaje_5  \
# count        21163.000000        21163.000000        21163.000000
# mean             0.009120            0.005670            0.037660
# std              0.095063            0.075089            0.190377
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%              0.000000            0.000000            0.000000
# 75%              0.000000            0.000000            0.000000
# max              1.000000            1.000000            1.000000
#
#        tipo_poblacion_R  tipo_poblacion_U
# count      21163.000000      21163.000000
# mean           0.342674          0.657326
# std            0.474615          0.474615
# min            0.000000          0.000000
# 25%            0.000000          0.000000
# 50%            0.000000          1.000000
# 75%            1.000000          1.000000
# max            1.000000          1.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Matriz de correlaciones

# %%
corr_matrix = encuesta_vivienda.corr()
corr_matrix
# Out:
#                     energia_electrica  refrigerador  lavadora  auto_propio  \
# energia_electrica            1.000000      0.195225  0.120957     0.042719
# refrigerador                 0.195225      1.000000  0.408165     0.252720
# lavadora                     0.120957      0.408165  1.000000     0.327438
# auto_propio                  0.042719      0.252720  0.327438     1.000000
# personas_vivienda            0.026123      0.017042  0.062718     0.038903
# mismo_gasto                  0.007772      0.008653  0.000552    -0.009614
# TLOC                        -0.057719     -0.176638 -0.188978    -0.160612
# ESTRATO                      0.068891      0.239313  0.270737     0.284317
# material_1                  -0.174999     -0.192302 -0.181279    -0.120385
# material_2                   0.000382     -0.168788 -0.219930    -0.264092
# material_3                   0.063547      0.240007  0.287415     0.309584
# fuente_agua_1                0.113592      0.316853  0.344846     0.295526
# fuente_agua_2               -0.021875     -0.236986 -0.274203    -0.251423
# fuente_agua_3               -0.007218     -0.045314 -0.055055    -0.031611
# fuente_agua_4               -0.128708     -0.114868 -0.100914    -0.055950
# fuente_agua_5               -0.048938     -0.061325 -0.065703    -0.043285
# fuente_agua_6               -0.110080     -0.116324 -0.103482    -0.087422
# conexion_drenaje_1           0.091208      0.173838  0.175463     0.162793
# conexion_drenaje_2          -0.023996     -0.087738 -0.102341    -0.123852
# conexion_drenaje_3           0.002501     -0.034092 -0.052408    -0.029981
# conexion_drenaje_4          -0.015472     -0.012307 -0.019214    -0.013740
# conexion_drenaje_5          -0.165125     -0.202155 -0.159582    -0.090215
# tipo_poblacion_R            -0.064046     -0.115899 -0.121404    -0.093391
# tipo_poblacion_U             0.064046      0.115899  0.121404     0.093391
#
#                     personas_vivienda  mismo_gasto      TLOC   ESTRATO  \
# energia_electrica            0.026123     0.007772 -0.057719  0.068891
# refrigerador                 0.017042     0.008653 -0.176638  0.239313
# lavadora                     0.062718     0.000552 -0.188978  0.270737
# auto_propio                  0.038903    -0.009614 -0.160612  0.284317
# personas_vivienda            1.000000     0.190140  0.077035 -0.132374
# mismo_gasto                  0.190140     1.000000 -0.015381 -0.005851
# TLOC                         0.077035    -0.015381  1.000000 -0.612761
# ESTRATO                     -0.132374    -0.005851 -0.612761  1.000000
# material_1                   0.018473     0.003248  0.097771 -0.148068
# material_2                   0.093000     0.013997  0.380712 -0.466925
# material_3                  -0.100281    -0.015263 -0.418609  0.523691
# fuente_agua_1               -0.069119     0.005557 -0.415869  0.503233
# fuente_agua_2                0.053968    -0.009310  0.350870 -0.389675
# fuente_agua_3                0.008730     0.011541  0.049418 -0.064395
# fuente_agua_4               -0.014427    -0.011036  0.064264 -0.071219
# fuente_agua_5                0.039126     0.006774  0.045316 -0.130780
# fuente_agua_6                0.021243     0.002314  0.148050 -0.192547
# conexion_drenaje_1          -0.035856     0.007572 -0.472792  0.480892
# conexion_drenaje_2           0.033978    -0.004431  0.396533 -0.397770
# conexion_drenaje_3           0.011919     0.005294  0.064882 -0.074540
# conexion_drenaje_4           0.001265     0.003659  0.071294 -0.051922
# conexion_drenaje_5           0.001972    -0.012396  0.173064 -0.193104
# tipo_poblacion_R             0.037020    -0.026605  0.862815 -0.476285
# tipo_poblacion_U            -0.037020     0.026605 -0.862815  0.476285
#
#                     material_1  material_2  ...  fuente_agua_4  fuente_agua_5  \
# energia_electrica    -0.174999    0.000382  ...      -0.128708      -0.048938
# refrigerador         -0.192302   -0.168788  ...      -0.114868      -0.061325
# lavadora             -0.181279   -0.219930  ...      -0.100914      -0.065703
# auto_propio          -0.120385   -0.264092  ...      -0.055950      -0.043285
# personas_vivienda     0.018473    0.093000  ...      -0.014427       0.039126
# mismo_gasto           0.003248    0.013997  ...      -0.011036       0.006774
# TLOC                  0.097771    0.380712  ...       0.064264       0.045316
# ESTRATO              -0.148068   -0.466925  ...      -0.071219      -0.130780
# material_1            1.000000   -0.197244  ...       0.057985       0.058921
# material_2           -0.197244    1.000000  ...       0.047207       0.080655
# material_3           -0.166955   -0.933664  ...      -0.068661      -0.102641
# fuente_agua_1        -0.201767   -0.372391  ...      -0.164586      -0.253279
# fuente_agua_2         0.129479    0.319879  ...      -0.054029      -0.083145
# fuente_agua_3         0.034994    0.043779  ...      -0.008291      -0.012759
# fuente_agua_4         0.057985    0.047207  ...       1.000000      -0.016983
# fuente_agua_5         0.058921    0.080655  ...      -0.016983       1.000000
# fuente_agua_6         0.109139    0.093109  ...      -0.020795      -0.032001
# conexion_drenaje_1   -0.139225   -0.255698  ...      -0.085675      -0.164118
# conexion_drenaje_2    0.080016    0.213487  ...       0.041571       0.157997
# conexion_drenaje_3    0.028565    0.046554  ...       0.004274       0.016042
# conexion_drenaje_4    0.017039    0.016457  ...      -0.007933      -0.004219
# conexion_drenaje_5    0.135248    0.098893  ...       0.115381       0.026313
# tipo_poblacion_R      0.075153    0.295321  ...       0.060216       0.046954
# tipo_poblacion_U     -0.075153   -0.295321  ...      -0.060216      -0.046954
#
#                     fuente_agua_6  conexion_drenaje_1  conexion_drenaje_2  \
# energia_electrica       -0.110080            0.091208           -0.023996
# refrigerador            -0.116324            0.173838           -0.087738
# lavadora                -0.103482            0.175463           -0.102341
# auto_propio             -0.087422            0.162793           -0.123852
# personas_vivienda        0.021243           -0.035856            0.033978
# mismo_gasto              0.002314            0.007572           -0.004431
# TLOC                     0.148050           -0.472792            0.396533
# ESTRATO                 -0.192547            0.480892           -0.397770
# material_1               0.109139           -0.139225            0.080016
# material_2               0.093109           -0.255698            0.213487
# material_3              -0.133513            0.308024           -0.243940
# fuente_agua_1           -0.310135            0.463990           -0.354682
# fuente_agua_2           -0.101809           -0.331786            0.253854
# fuente_agua_3           -0.015623           -0.070374            0.058833
# fuente_agua_4           -0.020795           -0.085675            0.041571
# fuente_agua_5           -0.032001           -0.164118            0.157997
# fuente_agua_6            1.000000           -0.184802            0.124832
# conexion_drenaje_1      -0.184802            1.000000           -0.885278
# conexion_drenaje_2       0.124832           -0.885278            1.000000
# conexion_drenaje_3       0.048856           -0.133444           -0.061057
# conexion_drenaje_4       0.008177           -0.105041           -0.048061
# conexion_drenaje_5       0.135446           -0.275167           -0.125903
# tipo_poblacion_R         0.123635           -0.442392            0.372637
# tipo_poblacion_U        -0.123635            0.442392           -0.372637
#
#                     conexion_drenaje_3  conexion_drenaje_4  \
# energia_electrica             0.002501           -0.015472
# refrigerador                 -0.034092           -0.012307
# lavadora                     -0.052408           -0.019214
# auto_propio                  -0.029981           -0.013740
# personas_vivienda             0.011919            0.001265
# mismo_gasto                   0.005294            0.003659
# TLOC                          0.064882            0.071294
# ESTRATO                      -0.074540           -0.051922
# material_1                    0.028565            0.017039
# material_2                    0.046554            0.016457
# material_3                   -0.057256           -0.022776
# fuente_agua_1                -0.077965           -0.041994
# fuente_agua_2                 0.055762            0.043164
# fuente_agua_3                 0.005104            0.018110
# fuente_agua_4                 0.004274           -0.007933
# fuente_agua_5                 0.016042           -0.004219
# fuente_agua_6                 0.048856            0.008177
# conexion_drenaje_1           -0.133444           -0.105041
# conexion_drenaje_2           -0.061057           -0.048061
# conexion_drenaje_3            1.000000           -0.007245
# conexion_drenaje_4           -0.007245            1.000000
# conexion_drenaje_5           -0.018978           -0.014939
# tipo_poblacion_R              0.055367            0.063485
# tipo_poblacion_U             -0.055367           -0.063485
#
#                     conexion_drenaje_5  tipo_poblacion_R  tipo_poblacion_U
# energia_electrica            -0.165125         -0.064046          0.064046
# refrigerador                 -0.202155         -0.115899          0.115899
# lavadora                     -0.159582         -0.121404          0.121404
# auto_propio                  -0.090215         -0.093391          0.093391
# personas_vivienda             0.001972          0.037020         -0.037020
# mismo_gasto                  -0.012396         -0.026605          0.026605
# TLOC                          0.173064          0.862815         -0.862815
# ESTRATO                      -0.193104         -0.476285          0.476285
# material_1                    0.135248          0.075153         -0.075153
# material_2                    0.098893          0.295321         -0.295321
# material_3                   -0.148868         -0.324466          0.324466
# fuente_agua_1                -0.255751         -0.335399          0.335399
# fuente_agua_2                 0.177145          0.273913         -0.273913
# fuente_agua_3                 0.025527          0.044568         -0.044568
# fuente_agua_4                 0.115381          0.060216         -0.060216
# fuente_agua_5                 0.026313          0.046954         -0.046954
# fuente_agua_6                 0.135446          0.123635         -0.123635
# conexion_drenaje_1           -0.275167         -0.442392          0.442392
# conexion_drenaje_2           -0.125903          0.372637         -0.372637
# conexion_drenaje_3           -0.018978          0.055367         -0.055367
# conexion_drenaje_4           -0.014939          0.063485         -0.063485
# conexion_drenaje_5            1.000000          0.162067         -0.162067
# tipo_poblacion_R              0.162067          1.000000         -1.000000
# tipo_poblacion_U             -0.162067         -1.000000          1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ### Visualizaciones

# %%
# Distribucion de Estratos socioeconomicos
sns.histplot(encuesta_vivienda["ESTRATO"])
# Out:
# <AxesSubplot:xlabel='ESTRATO', ylabel='Count'>

# %%
sns.histplot(encuesta_vivienda["TLOC"])
# Out:
# <AxesSubplot:xlabel='TLOC', ylabel='Count'>

# %%
sns.lineplot(data = encuesta_vivienda, x = "TLOC", y = "ESTRATO", ci = None)
# Out:
# <AxesSubplot:xlabel='TLOC', ylabel='ESTRATO'>

# %%
# Heatmap
plt.figure(figsize = (18,12))
sns.heatmap(corr_matrix, annot = True, cmap = "Blues")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Regresion lineal

# %%
# Ajuste de datos 
formula = "ESTRATO ~ material_3 + fuente_agua_1 + TLOC + tipo_poblacion_U + conexion_drenaje_1 + refrigerador + lavadora + auto_propio"
modelo_ols = ols(formula, encuesta_vivienda).fit()

# %%
# Revisar modelo
modelo_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                ESTRATO   R-squared:                       0.527
# Model:                            OLS   Adj. R-squared:                  0.527
# Method:                 Least Squares   F-statistic:                     2946.
# Date:                Sat, 30 Apr 2022   Prob (F-statistic):               0.00
# Time:                        21:21:54   Log-Likelihood:                -22613.
# No. Observations:               21163   AIC:                         4.524e+04
# Df Residuals:                   21154   BIC:                         4.532e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.5500      0.037     69.007      0.000       2.478       2.622
# material_3             0.4510      0.012     38.474      0.000       0.428       0.474
# fuente_agua_1          0.3126      0.014     22.867      0.000       0.286       0.339
# TLOC                  -0.3928      0.008    -50.904      0.000      -0.408      -0.378
# tipo_poblacion_U      -0.3539      0.020    -17.308      0.000      -0.394      -0.314
# conexion_drenaje_1     0.3507      0.012     28.339      0.000       0.326       0.375
# refrigerador           0.0494      0.017      2.886      0.004       0.016       0.083
# lavadora               0.0599      0.013      4.730      0.000       0.035       0.085
# auto_propio            0.1443      0.011     13.474      0.000       0.123       0.165
# ==============================================================================
# Omnibus:                       27.448   Durbin-Watson:                   0.514
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.410
# Skew:                          -0.011   Prob(JB):                     9.17e-08
# Kurtosis:                       3.191   Cond. No.                         28.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# prediccion modelo. Crear una Serie
Y_pred = pd.Series(modelo_ols.predict())

# %%
comparison = pd.concat([encuesta_vivienda["ESTRATO"], Y_pred], keys = ["ESTRATO", "ESTRATO_p"], axis = 1)
comparison
# Out:
#        ESTRATO  ESTRATO_p
# 0            2   2.515960
# 1            2   3.026857
# 2            2   3.171145
# 3            2   3.026857
# 4            2   2.466525
# ...        ...        ...
# 21158        2   1.895692
# 21159        2   1.691472
# 21160        2   1.751405
# 21161        2   1.751405
# 21162        2   2.346656
#
# [21163 rows x 2 columns]

# %%
# Crear columnas con errores

def calculate_errors(df):
    df["error"] = df.iloc[0:,0] - df.iloc[0:,1]
    df["sq_error"] = (df["error"])**2
    df["abs_error"] = abs(df["error"])
    
    return df

# %%
comparison = calculate_errors(comparison)
comparison
# Out:
#        ESTRATO  ESTRATO_p     error  sq_error  abs_error
# 0            2   2.515960 -0.515960  0.266215   0.515960
# 1            2   3.026857 -1.026857  1.054436   1.026857
# 2            2   3.171145 -1.171145  1.371580   1.171145
# 3            2   3.026857 -1.026857  1.054436   1.026857
# 4            2   2.466525 -0.466525  0.217646   0.466525
# ...        ...        ...       ...       ...        ...
# 21158        2   1.895692  0.104308  0.010880   0.104308
# 21159        2   1.691472  0.308528  0.095189   0.308528
# 21160        2   1.751405  0.248595  0.061800   0.248595
# 21161        2   1.751405  0.248595  0.061800   0.248595
# 21162        2   2.346656 -0.346656  0.120171   0.346656
#
# [21163 rows x 5 columns]

# %%
# Una pequena funcion para determinar metricas del modelo de regresion

def model_metrics(df):
    MAE = df["abs_error"].sum()/df["abs_error"].count()
    RMSE = (df["sq_error"].sum()/df["sq_error"].count())**(1/2)

    print("Model metrics")
    print("MAE: {} \t RMSE: {}".format(MAE, RMSE))

    return None

# %%
# MAE: Mean Absolute error
# RMSE: Root mean squared error
model_metrics(comparison)
# Out:
# Model metrics
# MAE: 0.5490078148166975 	 RMSE: 0.7043990103948065

# %% [markdown]
# # ML test

# %%
# Split data
train = encuesta_vivienda.sample(frac = 0.9, random_state = 200).reset_index()
test = encuesta_vivienda.drop(index = train.index).reset_index()

# %%
train_ols = ols(formula, train).fit()

# %%
# Review the model summary
train_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                ESTRATO   R-squared:                       0.528
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     2663.
# Date:                Sat, 30 Apr 2022   Prob (F-statistic):               0.00
# Time:                        21:21:57   Log-Likelihood:                -20372.
# No. Observations:               19047   AIC:                         4.076e+04
# Df Residuals:                   19038   BIC:                         4.083e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.5656      0.039     65.754      0.000       2.489       2.642
# material_3             0.4505      0.012     36.397      0.000       0.426       0.475
# fuente_agua_1          0.3118      0.014     21.565      0.000       0.283       0.340
# TLOC                  -0.3953      0.008    -48.442      0.000      -0.411      -0.379
# tipo_poblacion_U      -0.3554      0.022    -16.427      0.000      -0.398      -0.313
# conexion_drenaje_1     0.3480      0.013     26.570      0.000       0.322       0.374
# refrigerador           0.0397      0.018      2.197      0.028       0.004       0.075
# lavadora               0.0665      0.013      4.964      0.000       0.040       0.093
# auto_propio            0.1441      0.011     12.755      0.000       0.122       0.166
# ==============================================================================
# Omnibus:                       23.777   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.721
# Skew:                          -0.019   Prob(JB):                     9.56e-07
# Kurtosis:                       3.183   Cond. No.                         28.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Predict with the test set
y_pred_test = pd.Series(train_ols.predict(test))

# %%
# Create a df with the ground-truth Y and the predicted values
compare_df = pd.concat([test["ESTRATO"], y_pred_test], axis = 1, keys = ["ESTRATO", "ESTRATO_p"])

# %%
compare_df = calculate_errors(compare_df)
compare_df
# Out:
#       ESTRATO  ESTRATO_p     error  sq_error  abs_error
# 0           1   1.332553 -0.332553  0.110591   0.332553
# 1           1   1.710808 -0.710808  0.505248   0.710808
# 2           1   1.372257 -0.372257  0.138575   0.372257
# 3           1   1.332553 -0.332553  0.110591   0.332553
# 4           1   1.438742 -0.438742  0.192494   0.438742
# ...       ...        ...       ...       ...        ...
# 2111        2   1.894620  0.105380  0.011105   0.105380
# 2112        2   1.684028  0.315972  0.099838   0.315972
# 2113        2   1.750513  0.249487  0.062244   0.249487
# 2114        2   1.750513  0.249487  0.062244   0.249487
# 2115        2   2.345108 -0.345108  0.119099   0.345108
#
# [2116 rows x 5 columns]

# %%
# Metrics using the test set
model_metrics(comparison)
# Out:
# Model metrics
# MAE: 0.5490078148166975 	 RMSE: 0.7043990103948065
